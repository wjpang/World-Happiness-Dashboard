# %%
import pandas

# %%
whr = pandas.read_excel("data_raw/WHR2021-DataPanel.xls")
whr
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.370100        0.450662
# 1     Afghanistan  2009     4.401778            7.539972        0.552308
# 2     Afghanistan  2010     4.758381            7.646709        0.539075
# 3     Afghanistan  2011     3.831719            7.619532        0.521104
# 4     Afghanistan  2012     3.782938            7.705479        0.520637
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016     3.735400            7.984372        0.768425
# 1945     Zimbabwe  2017     3.638300            8.015738        0.754147
# 1946     Zimbabwe  2018     3.616480            8.048798        0.775388
# 1947     Zimbabwe  2019     2.693523            7.950132        0.759162
# 1948     Zimbabwe  2020     3.159802            7.828757        0.717243
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
whr.drop("Positive affect", inplace=True, axis=1)
whr.drop("Negative affect", inplace=True, axis=1)
whr
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.370100        0.450662
# 1     Afghanistan  2009     4.401778            7.539972        0.552308
# 2     Afghanistan  2010     4.758381            7.646709        0.539075
# 3     Afghanistan  2011     3.831719            7.619532        0.521104
# 4     Afghanistan  2012     3.782938            7.705479        0.520637
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016     3.735400            7.984372        0.768425
# 1945     Zimbabwe  2017     3.638300            8.015738        0.754147
# 1946     Zimbabwe  2018     3.616480            8.048798        0.775388
# 1947     Zimbabwe  2019     2.693523            7.950132        0.759162
# 1948     Zimbabwe  2020     3.159802            7.828757        0.717243
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
whr.rename(columns={"Country name": "Country", "year": "Year", "Life Ladder": "Happiness Score", "Healthy life expectancy at birth": "Life Expectancy", "Social support": "Social Support", "Freedom to make life choices": "Freedom Score", "Perceptions of corruption": "Perceptions of Corruption", "Log GDP per capita": "log(GDP per Capita)"}, inplace=True)
whr
# Out:
#           Country  Year  Happiness Score  log(GDP per Capita)  Social Support  \
# 0     Afghanistan  2008         3.723590             7.370100        0.450662
# 1     Afghanistan  2009         4.401778             7.539972        0.552308
# 2     Afghanistan  2010         4.758381             7.646709        0.539075
# 3     Afghanistan  2011         3.831719             7.619532        0.521104
# 4     Afghanistan  2012         3.782938             7.705479        0.520637
# ...           ...   ...              ...                  ...             ...
# 1944     Zimbabwe  2016         3.735400             7.984372        0.768425
# 1945     Zimbabwe  2017         3.638300             8.015738        0.754147
# 1946     Zimbabwe  2018         3.616480             8.048798        0.775388
# 1947     Zimbabwe  2019         2.693523             7.950132        0.759162
# 1948     Zimbabwe  2020         3.159802             7.828757        0.717243
#
# ...

# %%
whr.to_csv("data_clean/WHR_data_clean.csv", index=False)

# %%
mortality = pandas.read_excel("data_raw/WHR2021-MortalityData.xlsx")
mortality
# Out:
#           Country name  Population 2020  Population 2019  \
# 0        United States      331002647.0      328239523.0
# 1                Egypt      102334403.0      100388073.0
# 2              Morocco       36910558.0       36471769.0
# 3              Lebanon        6825442.0        6855713.0
# 4         Saudi Arabia       34813867.0       34268528.0
# ..                 ...              ...              ...
# 161              Yemen       29825968.0       29161922.0
# 162             Kosovo        1932774.0        1794248.0
# 163  Somaliland region              NaN              NaN
# 164       North Cyprus              NaN              NaN
# 165        South Sudan       11193729.0       11062113.0
#
#      COVID-19 deaths per 100,000 population in 2020  Median age  Island  \
# 0                                        104.451401   38.299999       0
# 1                                          7.456900   25.299999       0
# ...

# %%
mortality["Island"] = mortality["Island"].astype(bool)
mortality["WHO Western Pacific Region"] = mortality["WHO Western Pacific Region"].astype(bool)
mortality["Female head of government"] = mortality["Female head of government"].astype(bool)
mortality
# Out:
#           Country name  Population 2020  Population 2019  \
# 0        United States      331002647.0      328239523.0
# 1                Egypt      102334403.0      100388073.0
# 2              Morocco       36910558.0       36471769.0
# 3              Lebanon        6825442.0        6855713.0
# 4         Saudi Arabia       34813867.0       34268528.0
# ..                 ...              ...              ...
# 161              Yemen       29825968.0       29161922.0
# 162             Kosovo        1932774.0        1794248.0
# 163  Somaliland region              NaN              NaN
# 164       North Cyprus              NaN              NaN
# 165        South Sudan       11193729.0       11062113.0
#
#      COVID-19 deaths per 100,000 population in 2020  Median age  Island  \
# 0                                        104.451401   38.299999   False
# 1                                          7.456900   25.299999   False
# ...

# %%
mortality.rename(columns={"Country name": "Country", "Index of exposure to COVID-19  infections in other countries as of March 31": "Index of exposure to COVID-19 infections in other countries", "Log of average distance to SARS countries": "log(Average Distance to SARS countries)"}, inplace=True)
mortality
# Out:
#                Country  Population 2020  Population 2019  \
# 0        United States      331002647.0      328239523.0
# 1                Egypt      102334403.0      100388073.0
# 2              Morocco       36910558.0       36471769.0
# 3              Lebanon        6825442.0        6855713.0
# 4         Saudi Arabia       34813867.0       34268528.0
# ..                 ...              ...              ...
# 161              Yemen       29825968.0       29161922.0
# 162             Kosovo        1932774.0        1794248.0
# 163  Somaliland region              NaN              NaN
# 164       North Cyprus              NaN              NaN
# 165        South Sudan       11193729.0       11062113.0
#
#      COVID-19 deaths per 100,000 population in 2020  Median age  Island  \
# 0                                        104.451401   38.299999   False
# 1                                          7.456900   25.299999   False
# ...

# %%
mortality.to_csv("data_clean/WHR_mortality_clean.csv", index=False)

# %%
whr19_20 = pandas.read_csv("data_clean/WHR_data_clean.csv")

# %%
whr19_20 = whr19_20[whr19_20.Year >= 2019]
whr19_20
# Out:
#           Country  Year  Happiness Score  log(GDP per Capita)  Social Support  \
# 11    Afghanistan  2019         2.375092             7.697248        0.419973
# 23        Albania  2019         4.995318             9.544080        0.686365
# 24        Albania  2020         5.364910             9.497252        0.710115
# 32        Algeria  2019         4.744627             9.336946        0.803259
# 50      Argentina  2019         6.085561            10.000340        0.896371
# ...           ...   ...              ...                  ...             ...
# 1919        Yemen  2019         4.196913                  NaN        0.870043
# 1932       Zambia  2019         3.306797             8.154642        0.637894
# 1933       Zambia  2020         4.837992             8.116580        0.766872
# 1947     Zimbabwe  2019         2.693523             7.950132        0.759162
# 1948     Zimbabwe  2020         3.159802             7.828757        0.717243
#
# ...

# %%
whr19_20.drop("log(GDP per Capita)", inplace=True, axis=1)
whr19_20.drop("Social Support", inplace=True, axis=1)
whr19_20.drop("Life Expectancy", inplace=True, axis=1)
whr19_20.drop("Freedom Score", inplace=True, axis=1)
whr19_20.drop("Generosity", inplace=True, axis=1)
whr19_20.drop("Perceptions of Corruption", inplace=True, axis=1)
whr19_20.reset_index(inplace=True)
whr19_20.drop("index", inplace=True, axis=1)
whr19_20
# Out:
#          Country  Year  Happiness Score
# 0    Afghanistan  2019         2.375092
# 1        Albania  2019         4.995318
# 2        Albania  2020         5.364910
# 3        Algeria  2019         4.744627
# 4      Argentina  2019         6.085561
# ..           ...   ...              ...
# 234        Yemen  2019         4.196913
# 235       Zambia  2019         3.306797
# 236       Zambia  2020         4.837992
# 237     Zimbabwe  2019         2.693523
# 238     Zimbabwe  2020         3.159802
#
# [239 rows x 3 columns]

# %%
whr19_20 = whr19_20[whr19_20.duplicated(subset=["Country"], keep=False)]
whr19_20 = whr19_20.reset_index()
whr19_20 = whr19_20.drop("index", axis=1)
whr19_20
# Out:
#        Country  Year  Happiness Score
# 0      Albania  2019         4.995318
# 1      Albania  2020         5.364910
# 2    Argentina  2019         6.085561
# 3    Argentina  2020         5.900567
# 4    Australia  2019         7.233995
# ..         ...   ...              ...
# 181  Venezuela  2020         4.573830
# 182     Zambia  2019         3.306797
# 183     Zambia  2020         4.837992
# 184   Zimbabwe  2019         2.693523
# 185   Zimbabwe  2020         3.159802
#
# [186 rows x 3 columns]

# %%
whr19_20 = whr19_20.pivot_table(index="Country", columns="Year", values="Happiness Score").reset_index()
whr19_20
# Out:
# Year        Country      2019      2020
# 0           Albania  4.995318  5.364910
# 1         Argentina  6.085561  5.900567
# 2         Australia  7.233995  7.137368
# 3           Austria  7.195361  7.213489
# 4           Bahrain  7.098012  6.173176
# ..              ...       ...       ...
# 88    United States  6.943701  7.028088
# 89          Uruguay  6.600337  6.309681
# 90        Venezuela  5.080803  4.573830
# 91           Zambia  3.306797  4.837992
# 92         Zimbabwe  2.693523  3.159802
#
# [93 rows x 3 columns]

# %%
# whr19_20 = whr19_20["Happiness Change"] = whr19_20[2020] - whr19_20[2019]
# whr19_20
whr19_20.
# Out:
# Error: Kernel is dead
# at g._sendKernelShellControl (c:\Users\WJuin\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:1006305)
# at g.sendShellMessage (c:\Users\WJuin\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:1006074)
# at g.requestExecute (c:\Users\WJuin\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:1008616)
# at d.requestExecute (c:\Users\WJuin\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:37:328037)
# at S.requestExecute (c:\Users\WJuin\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:32:19306)
# at w.executeCodeCell (c:\Users\WJuin\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:300924)
# at w.execute (c:\Users\WJuin\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:300551)
# ...
